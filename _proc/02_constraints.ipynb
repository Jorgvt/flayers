# %% [raw]
# ---
# description: Avoid errors in calculations.
# output-file: constraints.html
# title: Constraints
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(Positive)
# Out:
# ---
#
# [source](https://github.com/Jorgvt/flayers/blob/master/flayers/constraints.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### Positive
#
# >      Positive ()
#
# Constraint to force positive weights in a layer.
